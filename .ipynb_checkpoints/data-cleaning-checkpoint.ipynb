# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_excel("datasets/2019_Annual_Summary.xls")
# Out:
# WARNING *** file size (96452) not 512 + multiple of sector size (512)

# %%
df.head()
# Out:
#   OE-417 Electric Emergency and Disturbance Report - Calendar Year 2019  \
# 0                                              Month
# 1                                           January
# 2                                            January
# 3                                            January
# 4                                            January
#
#          Unnamed: 1        Unnamed: 2           Unnamed: 3  \
# 0  Date Event Began  Time Event Began  Date of Restoration
# 1        01/05/2019          13:19:00           01/05/2019
# 2        01/06/2019          03:00:00           01/09/2019
# 3        01/06/2019          17:56:00           01/06/2019
# 4        01/06/2019          01:00:00           01/06/2019
#
#             Unnamed: 4                                         Unnamed: 5  \
# 0  Time of Restoration                                      Area Affected
# 1             15:07:00                                        Washington:
# ...
