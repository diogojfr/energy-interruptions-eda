# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_excel("datasets/2019_Annual_Summary.xls", skiprows=0, header=1)

# %%
orig_df = df

# %%
df.head(30)
# Out:
#        Month Date Event Began Time Event Began Date of Restoration  \
# 0   January        01/05/2019         13:19:00          01/05/2019
# 1    January       01/06/2019         03:00:00          01/09/2019
# 2    January       01/06/2019         17:56:00          01/06/2019
# 3    January       01/06/2019         01:00:00          01/06/2019
# 4    January       01/07/2019         20:57:00          01/07/2019
# 5    January       01/09/2019         11:55:00          01/09/2019
# 6    January       01/10/2019         12:19:00          01/10/2019
# 7    January       01/11/2019         11:36:00          01/11/2019
# 8    January       01/12/2019         11:30:00          01/13/2019
# 9    January       01/12/2019         11:30:00             Unknown
# 10   January       01/12/2019         19:20:00          01/12/2019
# 11   January       01/13/2019         05:30:00          01/15/2019
# 12   January       01/14/2019         11:10:00             Unknown
# 13   January       01/15/2019         08:00:00          01/15/2019
# 14   January       01/16/2019         17:26:00          01/17/2019
# 15   January       01/16/2019         05:19:00          01/16/2019
# 16   January       01/18/2019         21:54:00          01/19/2019
# 17   January       01/23/2019         07:26:00          01/23/2019
# 18   January       01/24/2019         04:39:00          01/24/2019
# 19   January       01/28/2019         13:35:00          01/28/2019
# 20   January       01/29/2019         18:34:00          01/29/2019
# 21   January       01/30/2019         16:30:00             Unknown
# 22   January       01/30/2019         04:23:00          02/02/2019
# 23   January       01/30/2019         09:30:00          01/31/2019
# 24   January       01/30/2019         07:00:00          01/30/2019
# 25   January       01/31/2019         21:33:00          01/31/2019
# 26  February       02/01/2019         23:57:00          02/02/2019
# 27  February       02/01/2019         05:35:00          02/01/2019
# 28  February       02/02/2019         10:28:00          02/02/2019
# 29  February       02/05/2019         18:17:00          02/05/2019
#
#    Time of Restoration                                      Area Affected  \
# 0             15:07:00                                        Washington:
# 1             07:00:00                                        Washington:
# 2             21:52:00                     California: Sacramento County;
# 3             12:00:00  Washington: King County, Thurston County, Pier...
# 4             21:32:00                                          Michigan:
# 5             11:56:00                       New Mexico: San Juan County;
# 6             12:48:00                            Montana: Valley County;
# 7             12:43:00                                             Maine:
# 8             22:00:00  Missouri: Jackson County; Kansas: Johnson County;
# 9              Unknown                                Missouri: Nebraska:
# 10            21:38:00                                     New Hampshire:
# 11            17:00:00                    North Carolina: South Carolina:
# 12             Unknown                                          Michigan:
# 13            08:02:00                                      Pennsylvania:
# 14            12:19:00                                        California:
# 15            07:14:00                              Texas: Nueces County;
# 16            00:19:00                                          Nebraska:
# 17            17:05:00                          Colorado: Larimer County;
# 18            05:16:00                                              Ohio:
# 19            13:40:00                                 Utah: Iron County;
# 20            18:36:00                      Louisiana: Washington Parish;
# 21             Unknown                                        Washington:
# 22            09:00:00                            Illinois: Scott County;
# 23            18:00:00                                          Michigan:
# 24            08:08:00                             Illinois: Pike County;
# 25            21:34:00                                        California:
# 26            08:49:00                                             Nevada
# 27            06:10:00                                      Massachusetts
# 28            10:29:00                                         California
# 29            20:26:00                                         California
#
#    NERC Region                                     Alert Criteria  \
# 0         WECC  Complete loss of Interpersonal Communication a...
# 1         WECC  Loss of electric service to more than 50,000 c...
# 2         WECC  Loss of electric service to more than 50,000 c...
# 3         WECC  Loss of electric service to more than 50,000 c...
# 4           RF  Complete loss of monitoring or control capabil...
# 5         WECC  Physical threat to its Facility excluding weat...
# 6         WECC  Unexpected Transmission loss within its area, ...
# 7           RF  Complete loss of monitoring or control capabil...
# 8       SPP RE  Loss of electric service to more than 50,000 c...
# 9         SERC  Loss of electric service to more than 50,000 c...
# 10        NPCC  Complete loss of monitoring or control capabil...
# 11        SERC  Loss of electric service to more than 50,000 c...
# 12          RF  Physical attack that could potentially impact ...
# 13          RF  Physical attack that could potentially impact ...
# 14        WECC  Loss of electric service to more than 50,000 c...
# 15         TRE  Complete loss of monitoring or control capabil...
# 16         MRO  Unexpected Transmission loss within its area, ...
# 17        WECC  Unexpected Transmission loss within its area, ...
# 18          RF  Complete loss of monitoring or control capabil...
# 19        WECC  Damage or destruction of its Facility that res...
# 20        SERC  Unexpected Transmission loss within its area, ...
# 21        WECC  Physical attack that could potentially impact ...
# 22        SERC  Fuel supply emergencies that could impact elec...
# 23          RF  Public appeal to reduce the use of electricity...
# 24        SERC  Fuel supply emergencies that could impact elec...
# 25        WECC  Damage or destruction of its Facility that res...
# 26        WECC  Damage or destruction of its Facility that res...
# 27        NPCC  Complete loss of monitoring or control capabil...
# 28        WECC  Physical attack that could potentially impact ...
# 29        WECC  Electrical System Separation (Islanding) where...
#
#                    Event Type Demand Loss (MW) Number of Customers Affected
# 0           System Operations                0                      Unknown
# 1              Severe Weather              230                       230000
# 2              Severe Weather              300                        90382
# 3              Severe Weather          Unknown                       230000
# 4           System Operations                0                            0
# 5         Suspicious Activity                0                            0
# 6           System Operations               11                            2
# 7           System Operations                0                            0
# 8              Severe Weather          Unknown                       112530
# 9              Severe Weather          Unknown                       116600
# 10          System Operations                0                            0
# 11             Severe Weather           133200                      Unknown
# 12     Actual Physical Attack          Unknown                      Unknown
# 13                  Vandalism                0                            0
# 14             Severe Weather              190                       126700
# 15          System Operations                0                            0
# 16  Transmission Interruption                8                      Unknown
# 17          System Operations                0                            0
# 18          System Operations                0                            0
# 19     Actual Physical Attack                0                            0
# 20  Transmission Interruption          Unknown                      Unknown
# 21                  Vandalism                0                            0
# 22     Fuel Supply Deficiency          Unknown                      Unknown
# 23             Severe Weather          Unknown                      Unknown
# 24             Severe Weather          Unknown                      Unknown
# 25                  Vandalism                0                            0
# 26                  Vandalism          Unknown                            1
# 27          System Operations                0                            0
# 28                  Vandalism                0                            0
# 29             Severe Weather               42                        33200

# %%
df.shape
# Out:
# (278, 11)

# %%
df.dtypes
# Out:
# Month                           object
# Date Event Began                object
# Time Event Began                object
# Date of Restoration             object
# Time of Restoration             object
# Area Affected                   object
# NERC Region                     object
# Alert Criteria                  object
# Event Type                      object
# Demand Loss (MW)                object
# Number of Customers Affected    object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Month                           0
# Date Event Began                0
# Time Event Began                0
# Date of Restoration             0
# Time of Restoration             0
# Area Affected                   0
# NERC Region                     0
# Alert Criteria                  0
# Event Type                      0
# Demand Loss (MW)                0
# Number of Customers Affected    0
# dtype: int64

# %%
df['Month'].value_counts()
# Out:
# June         31
# August       31
# October      29
# April        27
# July         26
# January      25
# February     25
# September    22
# November     20
# May          15
# December     15
# March        11
# January       1
# Name: Month, dtype: int64

# %%
df['Month'].unique()
# Out:
# array(['January ', 'January', 'February', 'March', 'April', 'May', 'June',
#        'July', 'August', 'September', 'October', 'November', 'December'],
#       dtype=object)

# %%
df['Event Type'].unique()
# Out:
# array(['System Operations', 'Severe Weather', 'Suspicious Activity',
#        'Actual Physical Attack', 'Vandalism', 'Transmission Interruption',
#        'Fuel Supply Deficiency',
#        'Severe Weather/Transmission Interruption',
#        'Generation Inadequacy',
#        'Severe Weather/Distribution Interruption',
#        'Distribution Interruption',
#        'Transmission Interruption/Distribution Interruption'],
#       dtype=object)

# %%
# columns to add
# 1.event duration (hours)
# 2. year
# 3. state (from 'Area affected')
# 

# columns to remove
# 'alert criteria'

# %%
# pandas concat example
# https://pandas.pydata.org/docs/reference/api/pandas.concat.html

# %%
# datetime example
#https://www.geeksforgeeks.org/calculate-time-difference-in-python/

#import datetime
#    
#time1 = datetime.datetime(2018, 10, 12, 20, 15, 40)
#time2 = datetime.datetime(2015, 2, 10, 15, 41, 30)
#  
#difference = time1 - time2 
#print('Difference is : ', difference)
#    
#minutes = divmod(difference.total_seconds(), 60) 
#print('Difference in minutes: ', minutes[0],
#      'minutes', minutes[1], 'seconds')
#    
#  
#minutes = divmod(difference.seconds, 60) 
#print('Total difference in minutes: ', minutes[0], 'minutes',minutes[1], 'seconds')

# %%
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.astype.html
